# %%
from santa.LinMHelper import LinMHelperApp

root = LinMHelperApp()
print('主程式結束。')
# Out:
# thread-0 Initialize
# thread-1 Initialize
# thread-2 Initialize
# thread-3 Initialize
# thread-0 Initialize
# Thread-0:wName=wsh5,HWND=11994530,profileName=騎士.ini
